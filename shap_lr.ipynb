# %%
! pip install shap
# Out:
# Requirement already satisfied: shap in c:\users\mjcro\anaconda3\lib\site-packages (0.46.0)
# Requirement already satisfied: numpy in c:\users\mjcro\anaconda3\lib\site-packages (from shap) (1.26.4)
# Requirement already satisfied: scipy in c:\users\mjcro\anaconda3\lib\site-packages (from shap) (1.13.1)
# Requirement already satisfied: scikit-learn in c:\users\mjcro\anaconda3\lib\site-packages (from shap) (1.4.2)
# Requirement already satisfied: pandas in c:\users\mjcro\anaconda3\lib\site-packages (from shap) (2.2.2)
# Requirement already satisfied: tqdm>=4.27.0 in c:\users\mjcro\anaconda3\lib\site-packages (from shap) (4.66.4)
# Requirement already satisfied: packaging>20.9 in c:\users\mjcro\anaconda3\lib\site-packages (from shap) (23.2)
# Requirement already satisfied: slicer==0.0.8 in c:\users\mjcro\anaconda3\lib\site-packages (from shap) (0.0.8)
# Requirement already satisfied: numba in c:\users\mjcro\anaconda3\lib\site-packages (from shap) (0.59.1)
# Requirement already satisfied: cloudpickle in c:\users\mjcro\anaconda3\lib\site-packages (from shap) (2.2.1)
# Requirement already satisfied: colorama in c:\users\mjcro\anaconda3\lib\site-packages (from tqdm>=4.27.0->shap) (0.4.6)
# Requirement already satisfied: llvmlite<0.43,>=0.42.0dev0 in c:\users\mjcro\anaconda3\lib\site-packages (from numba->shap) (0.42.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\mjcro\anaconda3\lib\site-packages (from pandas->shap) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\mjcro\anaconda3\lib\site-packages (from pandas->shap) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\mjcro\anaconda3\lib\site-packages (from pandas->shap) (2023.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\mjcro\anaconda3\lib\site-packages (from scikit-learn->shap) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\mjcro\anaconda3\lib\site-packages (from scikit-learn->shap) (2.2.0)
# Requirement already satisfied: six>=1.5 in c:\users\mjcro\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas->shap) (1.16.0)

# %%
import sklearn
import shap

# %%
# a classic housing price dataset
X, y = shap.datasets.california(n_points=1000)

X100 = shap.utils.sample(X, 100)  # 100 instances for use as the background distribution

# a simple linear model
model = sklearn.linear_model.LinearRegression()
model.fit(X, y)
# Out:
# LinearRegression()

# %%
print("Model coefficients:\n")
for i in range(X.shape[1]):
    print(X.columns[i], "=", model.coef_[i].round(5))
# Out:
# Model coefficients:
#
# MedInc = 0.42563
# HouseAge = 0.01033
# AveRooms = -0.1161
# AveBedrms = 0.66385
# Population = 3e-05
# AveOccup = -0.26096
# Latitude = -0.46734
# Longitude = -0.46272

# %%
shap.partial_dependence_plot(
    "MedInc",
    model.predict,
    X100,
    ice=False,
    model_expected_value=True,
    feature_expected_value=True,
)

# %%
# compute the SHAP values for the linear model
explainer = shap.Explainer(model.predict, X100)
shap_values = explainer(X)

# make a standard partial dependence plot
sample_ind = 20
shap.partial_dependence_plot(
    "MedInc",
    model.predict,
    X100,
    model_expected_value=True,
    feature_expected_value=True,
    ice=False,
    shap_values=shap_values[sample_ind : sample_ind + 1, :],
)
# Out:
# ExactExplainer explainer: 1001it [00:19, 48.78it/s]

# %%
shap.plots.scatter(shap_values[:, "MedInc"])

# %%
# the waterfall_plot shows how we get from shap_values.base_values to model.predict(X)[sample_ind]
shap.plots.waterfall(shap_values[sample_ind], max_display=14)
